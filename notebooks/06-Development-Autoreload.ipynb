# %% [markdown]
# # Autoreload
#
# Fully worked out example: https://gist.github.com/jbwhit/38c1035c48cdb1714fc8d47fa163bfae

# %%
# %reload_ext autoreload
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import os
import sys
import time
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.pyplot import GridSpec
import seaborn as sns
import numpy as np

sys.path.append("..")
sys.path.append("../autoreload_example/")

# %%
sns.set_context('poster', font_scale=1.3)

# %%
import sunglasses

# %%
import sharpie

# %%
# %autoreload 1
# %aimport sunglasses.first

# %%
# %aimport pandas

# %%
n_points = 100
x = np.random.rand(n_points) * 10.0
y = (np.random.randn(n_points) - 0.5) + 2.0 * np.sin(x)

# %%
sunglasses.first.plot_stuff(x, y)

# %%
sunglasses.first.plot_stuff2(x, y)

# %% [markdown]
# # I don't understand `pip install -e` option
#
# An example here of what that looks like.
#
# Finally got it to at least install.
#
# Had to run: `pip install -e .` from this top level (same level as `setup.py`)
#
# ```
# ├── __pycache__
# │   └── __init__.cpython-36.pyc
# ├── setup.py
# ├── sharpie
# │   ├── __init__.py
# │   └── first.py
# └── test_app.egg-info
#     ├── PKG-INFO
#     ├── SOURCES.txt
#     ├── dependency_links.txt
#     ├── not-zip-safe
#     └── top_level.txt```

# %%
from autoreload_example.sharpie.sharpie import first as shfirst

# %%
shfirst.plot_stuff(x, y)

# %%
# make edit c='r'
shfirst.plot_stuff(x, y)
